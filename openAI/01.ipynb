# %%
# %pip install python-dotenv
# Out:
# Requirement already satisfied: python-dotenv in c:\users\31799\appdata\local\programs\python\python313\lib\site-packages (1.1.1)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from openai import OpenAI
# client = OpenAI(api_key=os.environ["OPENAI_API_KEY"])
client = OpenAI()

response = client.responses.create(
    model = 'gpt-5-nano',
    input = '오늘 서울 서초구 날씨와 해당지역의 주말 날씨 알려줘 섭씨로 검색해서 답변해줘',
)

print(response.output_text)
# Out:
# 요청하신 내용은 실시간으로 웹에서 검색해 오늘 날씨와 주말 예보를 섭씨로 제공해야 하는데, 이 대화 환경에서는 제가 직접 웹 검색을 실행할 수 없습니다.
#
# 원하시면 제가 웹 검색 가능 여부를 확인하고 곧바로 Seocho-gu, Seoul의 오늘 날씨와 주말 예보를 섭씨로 찾아드리겠습니다. 웹 검색을 허용하시겠어요?
#
# 대안으로 바로 확인하는 방법도 안내드릴 수 있습니다:
# - 기상청(KMA) 날씨: 현재 날씨와 주간 예보를 신뢰성 있게 제공합니다.
# - 네이버 날씨, 카카오 날씨: 한국 사용자에게 친숙한 인터페이스로 오늘/주말 예보를 한눈에 볼 수 있습니다.
# - 해외 소스도 필요하면 The Weather Channel, AccuWeather 등에서 섭씨(Celsius) 표기로 확인 가능합니다.
#
# 확인해 주시면 바로 오늘 날씨와 이번 주말(토/일) 예보를 섭씨로 정리해 드리겠습니다.
